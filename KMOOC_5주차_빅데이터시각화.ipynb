# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/DALC_Scala/blob/main/KMOOC_5%EC%A3%BC%EC%B0%A8_%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Matplotlib 소개와 사용법
#
# *   파이썬의 대표적인 시각화 도구
# *   파이썬에서 그래프 표시를 가능하게 해줌
# *   축약어:mpl,plt
#
#
# 1.   간단한 소개와 설치방법및 사용법
# 2.   선그림(라인플롯) 점그림(스캐터플롯)
# 3.   다중서브플롯(여러개의 그림이 나란히)

# %% [markdown]
# ---

# %% [markdown]
# 다양한 포맷으로 그림 저장

# %%
plt.savfig('my_figure.jpg')

# %%
from google.colab import files
files.download('my_figure.jpg')

# %% [markdown]
# 기본스타일 설정

# %%
plt.style.use('classic')

# %% [markdown]
# 단순하고 편리한 MATLAB 스타일 ![image.png](data:image/png;base64,...)

# %% [markdown]
# 복잡하고 상세한 객체지향 스타일
# ![화면 캡처 2021-04-30 163157.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# y=f(x)시각화 //선그림

# %%
# %matpltlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
fig = plt.figure()
ax = plt.axes()

# %%
plt.plot(x,y);
ax=plt.axes()

# %%
plt.plot(x,np.sin(x))

# %% [markdown]
# 선의 색 변경 : color

# %% [markdown]
# ![화면 캡처 2021-04-30 164530.jpg](data:image/jpeg;base64,...)

# %%
plt.plot(x,x+0,'-g')
plt.plot(x,x+1,'--c')
plt.plot(x,x+2,'-.k')
plt.plot(x,x+3,':r')

# %% [markdown]
# 축의 범위 지정
#
#
# *   plt.xlim()
# *   plt.ylim()
#
# 상하 좌우 반전
# : 인수 순서 바꾸기

# %%
plt.plot(x,np.cos(x*2))
plt.axis([-1,11,-1.5,1.5])

# %% [markdown]
# 축의 스케일 변경
# <br>예:로그스케일
#
#
# *   plt.xscale()
# *   plt.yscale()
# {"log","linear","symlog","logit"}

# %% [markdown]
# 축의 레이블 추가:부가적 설명<br>
# ![화면 캡처 2021-04-30 165248.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 범례 추가<br>
# ![화면 캡처 2021-04-30 165342.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# 점그림(산점도)

# %%
x=np.linspace(0,10,25)
plt.plot(x,x,'o',color='r')
plt.plot(x,x+2,'.',color='g')
plt.plot(x,x+4,'s-',color='b')
plt.plot(x,x+6,'d--',color='c')

# %%
plt.plot(x,np.sin(x),'-og')

# %% [markdown]
# ![화면 캡처 2021-04-30 165845.jpg](data:image/jpeg;base64,...)

# %%
plt.scatter(x,y,marker='o')

# %% [markdown]
# ![화면 캡처 2021-04-30 170002.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# 서브플롯 각각 생성 : subplot()<br>
# 한꺼번에 생성 : subplots() <br>
# 복잡한 형태의 서브플롯 생성 : GridSpec()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

nrows,ncols=3,4

for i in range(nrows*ncols):
  plt.subplot(nrows,ncols,i+1)
  plt.text(0.5,0.5,str((nrows,ncols,i+1)),fontsize=16,ha='center')

# %%
# %matplotlib inline

for i in range(nrows*ncols):
  plt.subplot(nrows,ncols,i+1)
  plt.text(0.5,0.5,str((nrows,ncols,i+1)),fontsize=16,ha='center')

  fig = plt.figure()
  fig.subplots_adjust(hspace=0.4,wspace=0.4)

  nrows,ncols=3,4

  for i in range(nrows*ncols):
    plt.subplot(nrows,ncols,i+1)
    plt.text(0.5,0.5,str((nrows,ncols,i+1)),
             fontsize=16,ha='center')

# %% [markdown]
# ![화면 캡처 2021-04-30 171207.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 복잡한 형태와 크기:plt.GridSpec()

# %% [markdown]
# ![화면 캡처 2021-04-30 171326.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![화면 캡처 2021-04-30 171355.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![화면 캡처 2021-04-30 171520.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![화면 캡처 2021-04-30 171540.jpg](data:image/jpeg;base64,...)
