# %% [markdown]
# # Colab 실습 하기

# %% [markdown]
# ## 1. 마크다운으로 내 깃허브 링크 삽입하기
# https://github.com/yoojinlee-hub/

# %% [markdown]
# ## 2. 마크다운으로 이미지 삽입하기
#
# - 이미지는 인터넷에 있는 이미지 아무거나 또는 내 pc에 저장되어 있는 아무이미지를 삽입해주시면 됩니다.
#
# ![zoom 배경.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 3. 마크다운으로 수업 배운 것 정리해보기
# - 전공수업, 교양 수업, 오늘 ot내용, 요즘 준비하는 자격증 내용 등등 기타 자기가 최근 배운 것 아무거나 최소 3줄이상 작성해주세요. (이때 단어강조하기, 문장 띄어쓰기, 인용구등 사용하기)
#
# GitHub에서 계속 오류가 났지만 동아리 **운영진분들 덕분에** 잘 해결할 수 있었습니다.
# 요즘 인*터넷프로그래밍을 통해 html*을 배우고, *`프로그래밍논리의 이해를 통해 c언어`*를 배우는데, 둘이 머리속에서 섞여서 헷갈립니다. 더 열심히 공부하겠습니다.
