# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/DALC_Scala/blob/main/KMooc_7_%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EB%A5%98%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **빅데이터 분류분석**
#
#
# *   분류분석의 개념과 절차
# *   초모수와 모델검증방법
# * 나이브베이즈 기법
# ![화면 캡처 2021-05-13 085907.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-13 085918.png](data:image/png;base64,...)
#
# * 이산적 - 분류분석
# * 연속적 - 회귀분석

# %% [markdown]
# ![화면 캡처 2021-05-13 090108.png](data:image/png;base64,...)
# 이산적인 범주형 레이블: 지수가 몇 개의 등급으로 표현

# %% [markdown]
# 분류분석
#
# *   레이블 범주, 클래스 등이 이산적인 경우에 데이터 세트의 특징 배열데이터를 학습하여 어떤 레이블에 해당하는지 분류하는 모델을 찾는 기법
# * ![화면 캡처 2021-05-13 090319.png](data:image/png;base64,...)
# * ![화면 캡처 2021-05-13 090434.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-13 090604.png](data:image/png;base64,...)

# %% [markdown]
# 예측
#
# ![화면 캡처 2021-05-13 090629.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-13 090820.png](data:image/png;base64,...)

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris.head(4)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa

# %%
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# GaussianNB : 처리속도가 아주 빠르고 초모수를 선택할 필요가 없음- 기본분류기로 사용하기에 적합

# %%
model=GaussianNB()

from sklearn.model_selection import train_test_split
Xtrain,Xtest,ytrain,ytest=train_test_split(X_iris,y_iris,test_size=0.25, random_state=1)

# %%
model.fit(Xtrain,ytrain)
y_model=model.predict(Xtest)

# %% [markdown]
# ![화면 캡처 2021-05-13 091519.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **초모수와 모델 검증**
#
# 머신러닝 지도학습의 분석절차
# ![화면 캡처 2021-05-13 091926.png](data:image/png;base64,...)

# %% [markdown]
# *   초모수: 학습을 통해 추정되지 않은 모델 모수
# *   성공적인 지도학습은 정확도가 높은 모델을 찾아내는 것

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# *   모델과 초모수 선택
# *   훈련 데이터로 모델 훈련
# *   계산된 예측 값과 실제값 비교
# * ![화면 캡처 2021-05-13 092332.png](data:image/png;base64,...)

# %%
model=KNeighborsClassifier(n_neighbors=1)

import seaborn as sns
iris = sns.load_dataset('iris')
X = iris
y = iris.target

# %%
model.fit(x,y)

# %% [markdown]
# ![화면 캡처 2021-05-13 092533.png](data:image/png;base64,...)

# %% [markdown]
# ~ 모델을 훈련한 데이터와 동일한 데이터로 모델 검증 . 잘못된 방식의 모델 검증임.

# %%
from sklearn.model_selection import train_test_split
X1,X2,y1,y2 = train_test_split(X,y,random_state=0,train_size=0.5)

# %% [markdown]
# ![화면 캡처 2021-05-13 092838.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-13 092845.png](data:image/png;base64,...)

# %% [markdown]
# **교차 검증**: 데이터의 양이 충분하지 않을 때 사용![화면 캡처 2021-05-13 092948.png](data:image/png;base64,...)

# %%
y1_model=model.fit(X1,y1).predict(X2)
y2_model=model.fit(X2,y2).predict(X1)
score1=accuracy_score(y1,y1_model)
score2=accuracy_score(y2,y2_model)
score = (score1+score2)/2
print(score)

# %% [markdown]
# ![화면 캡처 2021-05-13 093219.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-13 093243.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **나이브 베이즈 분류기법**: 두 확률 사이에 존재하는 관계 정리
#
# *   베이즈 정리
# *   가우시안 나이브 베이즈 기법(정규확률분포)
# * ![화면 캡처 2021-05-13 093546.png](data:image/png;base64,...)

# %% [markdown]
# 생성모델: 각 레이블에 대한 특징 데이터의 확률값을 계산![화면 캡처 2021-05-13 093645.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-13 093715.png](data:image/png;base64,...)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns;sns.set()

# %% [markdown]
# ![화면 캡처 2021-05-13 093827.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-13 093908.png](data:image/png;base64,...)

# %% [markdown]
# **가우시안 생성 모델**
#
# *   전제: 차원사이에 공분산이 없는(데이터 생성과정에서 설명한 등방성과 같은 의미:가로방향과 세로방향의 데이터 분포가 서로 영향을 주지 않고 독립적으로 결정된다) 가우스 분포를 따른다
# *   이 모델은 단순히 각 레이블 내의 평균과 표준편차를 구하여 적합할 수 있다.
# * 각 색상의 타원은 타원의 중심으로 갈수록 확률이 더 커지는 각 레이블에 대한 가우스 생성 모델을 나타냄
# * ![화면 캡처 2021-05-13 094133.png](data:image/png;base64,...)

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB
model.fit(X,y)
rng=np.random.RandomState(0)
Xnew=[-6,-14]+[14,18]*rng.rand(2000,2)
ynew=model.predict(Xnew)

# %% [markdown]
# ![화면 캡처 2021-05-13 094428.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-13 094448.png](data:image/png;base64,...)

# %% [markdown]
# 확률 표현의 장점
# ![화면 캡처 2021-05-13 094519.png](data:image/png;base64,...)
