# %% [markdown]
# <a href="https://colab.research.google.com/github/yoojinlee-hub/DALC_Scala/blob/main/KMOOC_8_%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%EA%B5%B0%EC%A7%91%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **빅데이터 군집분석**<br>
# ![화면 캡처 2021-05-20 183957.png](data:image/png;base64,...)

# %% [markdown]
# *머신러닝의 비지도 학습의 개념*<br>![화면 캡처 2021-05-20 184052.png](data:image/png;base64,...)

# %% [markdown]
# *   머신러닝의 일종
# *   데이터 어떻게 구성되었는지를 알아내는 문제의 범주에 속함
# *   지도학습과는 다르게 레이블이 없거나 참조하지 않음
# * *데이터 세트가 스스로 데이터를 설명하게 하는 것*

# %% [markdown]
# ![화면 캡처 2021-05-20 184344.png](data:image/png;base64,...)

# %% [markdown]
# **군집화**<br>
#
#
# *   각각의 그룹의 성질을 분석하고 의미를 부여해서 레이블을 새로 할당할 수 있음
# *   사전에 할당된 레이블이 있는 경우라도 적용 가능
# * 군집분석을 통해 동일하게 묶인 데이터세트로 지도학습수행도 가능
# * 지도학습의 선행단계로 사용할 수 있음

# %% [markdown]
# K 평균 알고리즘: k개의 군집중심으로 구성된 모델에 데이터를 적합시키는 방법. 할당된 중심으로부터 각 점까지의 거리를 최소화 하는 점이 최적의 중심점<br>![화면 캡처 2021-05-20 184758.png](data:image/png;base64,...)

# %% [markdown]
# **차원축소**<br>
#
#
# *   레이블이나 다른 정보를 데이터  세트 자체의  구조로부터 추론하는 방식
# *   전체 데이터 세트의 품질을 떨어뜨리지 않으면서 차원의 개수를 줄이는 표현방식을 찾아내는 방법
# <br>

# %% [markdown]
# ![화면 캡처 2021-05-20 185013.png](data:image/png;base64,...)

# %% [markdown]
# 데이터를 표현하는 차원의 수를 줄여도 데이터의 구조 변화 없음.
# 고차원 데이터일수록 효과적.  머신러닝의 결과를 높이기 위한 보조 수단으로 사용

# %% [markdown]
# ---

# %% [markdown]
# **k-평균 군집화**
#
#
# *   레이블이 없는 다차원 데이터세트 내에 사전정의된 개수만큼의 군집으로 데이터를 묶어냄
# ![화면 캡처 2021-05-20 185323.png](data:image/png;base64,...)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns;sns.set()
import numpy as np

# %% [markdown]
# ![화면 캡처 2021-05-20 185502.png](data:image/png;base64,...)

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=4)

# %% [markdown]
# k평균 군집 분석은 군집 중심의 수를 변경하면서 최적의 군집을 만드는 군집 중심의 수를 찾는다.

# %%
kmeans.fit(X)
y_kmeans=kmeans.predict(X)

# %%
centers = kmeans.cluster_centers_
plt.scatter(centers[:,0],centers[:,1],c='black',s=200,alpha=0.5);

# %%
plt.scatter(X[:,0],X[:,1],c=y_kmeans,cmap='viridis');

# %% [markdown]
# ![화면 캡처 2021-05-20 190029.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 190056.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 190105.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 190130.png](data:image/png;base64,...)

# %%
from sklearn.datasets import load_digits
digits = load_digits()
for i in range(3):
for j in range(5):
  ax[i][j].axis('off')
  ax[i][j].imshow(digits.data[i*4+j].reshape(8,8),cmap='binary',);

# %% [markdown]
# ![화면 캡처 2021-05-20 190529.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 190554.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 190613.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# **가우스 혼합 모델**
#
#
# *   k평균 알고리즘의 약점을 해결하기 위한 모델
# *   ![화면 캡처 2021-05-20 190806.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 190849.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 190907.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 190923.png](data:image/png;base64,...)

# %% [markdown]
# k평균 모델에는 군집할당의 확률, 불확실성에 대한 기준이 없음

# %% [markdown]
# ![화면 캡처 2021-05-20 191107.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 191156.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 191255.png](data:image/png;base64,...)

# %%
from sklearn.mixture import GaussianMixture
gmm = GaussianMixture(n_components=4).fit(X)
labels = gmm.predict(X)
plt.scatter(X[:,0],X[:,1],c=labels,s=40,cmap='viridis')c='red');

# %% [markdown]
# ![화면 캡처 2021-05-20 191540.png](data:image/png;base64,...)

# %%
probs = gmm.predict_proba(X)
print(probs[:5].round(3))

# %% [markdown]
# ![화면 캡처 2021-05-20 191642.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 191708.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 191731.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 191747.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 191758.png](data:image/png;base64,...)

# %% [markdown]
# ![화면 캡처 2021-05-20 191833.png](data:image/png;base64,...)
